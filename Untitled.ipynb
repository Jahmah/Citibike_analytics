# %%
import os
import pandas as pd
import glob

# %%
### Merge 2017 files - January to March

# %%
input_file = "data\JCC-2017-*.csv"

# %%
all_files = glob.glob(os.path.join(input_file, 'JC-2017*.csv' ))

# %%
all_files
# Out:
# ['data\\JCC-2017-01-citibike-tripdata.csv\\JC-201701-citibike-tripdata.csv',
#  'data\\JCC-2017-02-citibike-tripdata.csv\\JC-201702-citibike-tripdata.csv',
#  'data\\JCC-2017-03-citibike-tripdata.csv\\JC-201703-citibike-tripdata.csv']

# %%
all_data_frames = []

for file in all_files:
    df = pd.read_csv(file, index_col=None)
    all_data_frames.append(df)
    
df_concat = pd.concat(all_data_frames, axis= 0, ignore_index = True, sort = False, join="outer")

# %%
df_concat.rename(columns = {'Trip Duration': 'tripduration', 'Start Time': 'starttime', 
                           'Stop Time': 'stoptime', 'Gender':'gender', "User Type": "usertype",
                           'Bike ID': 'bikeid', 'Birth Year': 'birth year', 'Start Station ID': 'start station id',
                           'Start Station Name': 'start station name', 'Start Station Latitude': 'start station latitude',
                           'Start Station Longitude': 'start station longitude', 'End Station ID': 'end station id', 
                           'End Station Name': 'end station name', 'End Station Latitude': 'end station latitude',
                           'End Station Longitude': 'end station longitude'}, inplace = True)

# %%
#df_concat

# %%
#df_concat.to_csv('data/citybike2017-01.csv', sep=',')

# %%
### Merge 2017 files - April to December

# %%
input_file1 = "data\JC-2017*.csv"

# %%
all_files1 = glob.glob(os.path.join(input_file1, 'JC-2017*.csv' ))

# %%
#all_files1
# Out:
# ['data\\JC-201704-citibike-tripdata.csv\\JC-201704-citibike-tripdata.csv',
#  'data\\JC-201705-citibike-tripdata.csv\\JC-201705-citibike-tripdata.csv',
#  'data\\JC-201706-citibike-tripdata.csv\\JC-201706-citibike-tripdata.csv',
#  'data\\JC-201707-citibike-tripdata.csv\\JC-201707-citibike-tripdata.csv',
#  'data\\JC-201708-citibike-tripdata.csv\\JC-201708 citibike-tripdata.csv',
#  'data\\JC-201709-citibike-tripdata.csv\\JC-201709-citibike-tripdata.csv',
#  'data\\JC-201710-citibike-tripdata.csv\\JC-201710-citibike-tripdata.csv',
#  'data\\JC-201711-citibike-tripdata.csv\\JC-201711-citibike-tripdata.csv',
#  'data\\JC-201712-citibike-tripdata.csv\\JC-201712-citibike-tripdata.csv']

# %%
all_data_frames1 = []

for file in all_files1:
    df1 = pd.read_csv(file, index_col=None)
    all_data_frames1.append(df1)
    
df_concat1 = pd.concat(all_data_frames1, axis= 0, ignore_index = True, sort = False, join="outer")

# %%
#df_concat1

# %%
df_concat1.to_csv('data/citybike2017-02.csv', sep=',')

# %%
merged_files = pd.concat([df_concat, df_concat1], join='outer', sort= False)

# %%
#merged_files

# %%
merged_files.to_csv('data/allcitybike2017.csv')

# %%
### Merge 2016 files

# %%
input_file3 = "data\JC-2016*.csv"

# %%
all_files3 = glob.glob(os.path.join(input_file3, 'JC-2016*.csv' ))

# %%
all_files3
# Out:
# ['data\\JC-201601-citibike-tripdata.csv\\JC-20161-citibike-tripdata.csv',
#  'data\\JC-201602-citibike-tripdata.csv\\JC-20162-citibike-tripdata.csv',
#  'data\\JC-201603-citibike-tripdata.csv\\JC-20163-citibike-tripdata.csv',
#  'data\\JC-201604-citibike-tripdata.csv\\JC-201604-citibike-tripdata.csv',
#  'data\\JC-201605-citibike-tripdata.csv\\JC-201605-citibike-tripdata.csv',
#  'data\\JC-201606-citibike-tripdata.csv\\JC-201606-citibike-tripdata.csv',
#  'data\\JC-201607-citibike-tripdata.csv\\JC-201607-citibike-tripdata.csv',
#  'data\\JC-201608-citibike-tripdata.csv\\JC-201608-citibike-tripdata.csv',
#  'data\\JC-201609-citibike-tripdata.csv\\JC-201609-citibike-tripdata.csv',
#  'data\\JC-201610-citibike-tripdata.csv\\JC-201610-citibike-tripdata.csv',
#  'data\\JC-201611-citibike-tripdata.csv\\JC-201611-citibike-tripdata.csv',
#  'data\\JC-201612-citibike-tripdata.csv\\JC-201612-citibike-tripdata.csv']

# %%
all_data_frames3 = []

for file in all_files3:
    df3 = pd.read_csv(file, index_col=None)
    all_data_frames3.append(df3)
    
df_concat2 = pd.concat(all_data_frames3, axis= 0, ignore_index = True, sort = False, join="outer")

# %%
df_concat2
# Out:
#         Trip Duration           Start Time            Stop Time  \
# 0                 362  2016-01-01 00:02:52  2016-01-01 00:08:54
# 1                 200  2016-01-01 00:18:22  2016-01-01 00:21:42
# 2                 202  2016-01-01 00:18:25  2016-01-01 00:21:47
# 3                 248  2016-01-01 00:23:13  2016-01-01 00:27:21
# 4                 903  2016-01-01 01:03:20  2016-01-01 01:18:24
# 5                 883  2016-01-01 01:03:28  2016-01-01 01:18:11
# 6                 445  2016-01-01 01:07:45  2016-01-01 01:15:11
# 7                 192  2016-01-01 01:18:51  2016-01-01 01:22:03
# 8                 409  2016-01-01 01:23:44  2016-01-01 01:30:34
# 9                 285  2016-01-01 01:25:12  2016-01-01 01:29:57
# 10                206  2016-01-01 01:45:34  2016-01-01 01:49:00
# 11                251  2016-01-01 02:02:55  2016-01-01 02:07:06
# 12                292  2016-01-01 02:20:38  2016-01-01 02:25:30
# 13                175  2016-01-01 02:23:37  2016-01-01 02:26:32
# ...

# %%
df_concat2.rename(columns = {'Trip Duration': 'tripduration', 'Start Time': 'starttime', 
                           'Stop Time': 'stoptime', 'Gender':'gender', "User Type": "usertype",
                           'Bike ID': 'bikeid', 'Birth Year': 'birth year', 'Start Station ID': 'start station id',
                           'Start Station Name': 'start station name', 'Start Station Latitude': 'start station latitude',
                           'Start Station Longitude': 'start station longitude', 'End Station ID': 'end station id', 
                           'End Station Name': 'end station name', 'End Station Latitude': 'end station latitude',
                           'End Station Longitude': 'end station longitude'}, inplace = True)

# %%
df_concat2
# Out:
#         tripduration            starttime             stoptime  \
# 0                362  2016-01-01 00:02:52  2016-01-01 00:08:54
# 1                200  2016-01-01 00:18:22  2016-01-01 00:21:42
# 2                202  2016-01-01 00:18:25  2016-01-01 00:21:47
# 3                248  2016-01-01 00:23:13  2016-01-01 00:27:21
# 4                903  2016-01-01 01:03:20  2016-01-01 01:18:24
# 5                883  2016-01-01 01:03:28  2016-01-01 01:18:11
# 6                445  2016-01-01 01:07:45  2016-01-01 01:15:11
# 7                192  2016-01-01 01:18:51  2016-01-01 01:22:03
# 8                409  2016-01-01 01:23:44  2016-01-01 01:30:34
# 9                285  2016-01-01 01:25:12  2016-01-01 01:29:57
# 10               206  2016-01-01 01:45:34  2016-01-01 01:49:00
# 11               251  2016-01-01 02:02:55  2016-01-01 02:07:06
# 12               292  2016-01-01 02:20:38  2016-01-01 02:25:30
# 13               175  2016-01-01 02:23:37  2016-01-01 02:26:32
# ...

# %%
df_concat2.to_csv('data/allcitybike2016.csv')

# %%
### Merge all 2018 csv files

# %%
input_file4 = "data\JC-2018*.csv"

# %%
all_files4 = glob.glob(os.path.join(input_file4, 'JC-2018*.csv' ))

# %%
all_files4
# Out:
# ['data\\JC-201801-citibike-tripdata.csv\\JC-201801-citibike-tripdata.csv',
#  'data\\JC-201802-citibike-tripdata.csv\\JC-201802-citibike-tripdata.csv',
#  'data\\JC-201803-citibike-tripdata.csv\\JC-201803-citibike-tripdata.csv',
#  'data\\JC-201804-citibike-tripdata.csv\\JC-201804-citibike-tripdata.csv',
#  'data\\JC-201805-citibike-tripdata.csv\\JC-201805-citibike-tripdata.csv',
#  'data\\JC-201806-citibike-tripdata.csv\\JC-201806-citibike-tripdata.csv',
#  'data\\JC-201807-citibike-tripdata.csv\\JC-201807-citibike-tripdata.csv',
#  'data\\JC-201808-citibike-tripdata.csv\\JC-201808-citibike-tripdata.csv',
#  'data\\JC-201809-citibike-tripdata.csv\\JC-201809-citibike-tripdata.csv']

# %%
all_data_frames4 = []

for file in all_files4:
    df4 = pd.read_csv(file, index_col=None)
    all_data_frames4.append(df4)
    
df_concat3 = pd.concat(all_data_frames4, axis= 0, ignore_index = True, sort = False, join="outer")

# %%
df_concat3
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1                550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2                510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3                354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4                250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# 5                613  2018-01-01 22:05:05.8740  2018-01-01 22:15:19.4190
# 6                290  2018-01-02 12:13:51.7940  2018-01-02 12:18:42.1070
# 7                381  2018-01-02 12:50:03.3430  2018-01-02 12:56:24.6440
# 8                318  2018-01-02 13:55:58.2430  2018-01-02 14:01:16.8810
# 9               1852  2018-01-02 16:55:29.6390  2018-01-02 17:26:22.3050
# 10               460  2018-01-02 17:01:50.5860  2018-01-02 17:09:31.4340
# 11               403  2018-01-02 17:05:12.2360  2018-01-02 17:11:55.2630
# ...

# %%
df_concat3.to_csv('data/allcitybike2018.csv')
